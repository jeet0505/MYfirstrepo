# %% [markdown]
# #### IMDB DATA ANALYSIS

# %%
import pandas as pd
import numpy as np

# %%
imdb = pd.read_csv("imdb_data.csv")

# %%
imdb.drop('genres', axis = 1) # axis = 1 to do the task along columns
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                homepage    imdb_id original_language  \
# ...

# %%
imdb.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
type(imdb)
# Out:
# pandas.core.frame.DataFrame

# %%
imdb.shape
# Out:
# (3000, 23)

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
imdb.describe().T
# Out:
#              count          mean           std       min           25%  \
# id          3000.0  1.500500e+03  8.661697e+02  1.000000  7.507500e+02
# budget      3000.0  2.253133e+07  3.702609e+07  0.000000  0.000000e+00
# popularity  3000.0  8.463274e+00  1.210400e+01  0.000001  4.018053e+00
# runtime     2998.0  1.078566e+02  2.208643e+01  0.000000  9.400000e+01
# revenue     3000.0  6.672585e+07  1.375323e+08  1.000000  2.379808e+06
#
#                      50%           75%           max
# id          1.500500e+03  2.250250e+03  3.000000e+03
# budget      8.000000e+06  2.900000e+07  3.800000e+08
# popularity  7.374861e+00  1.089098e+01  2.943370e+02
# runtime     1.040000e+02  1.180000e+02  3.380000e+02
# revenue     1.680707e+07  6.891920e+07  1.519558e+09

# %%
imdb['original_language'].value_counts()
# Out:
# original_language
# en    2575
# fr      78
# ru      47
# es      43
# hi      42
# ja      37
# it      24
# cn      20
# ko      20
# zh      19
# de      18
# ta      16
# sv       8
# nl       6
# pt       6
# fa       5
# da       5
# ro       4
# hu       3
# tr       3
# no       2
# ml       2
# pl       2
# te       2
# fi       2
# ur       1
# he       1
# el       1
# ar       1
# nb       1
# vi       1
# mr       1
# cs       1
# sr       1
# bn       1
# id       1
# Name: count, dtype: int64

# %%
imdb['original_language'] == 'hi'
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Name: original_language, Length: 3000, dtype: bool

# %%
imdb_cond = imdb['original_language'] == 'hi'  # condition file

# %%
imdb_cond
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Name: original_language, Length: 3000, dtype: bool

# %%
imdb1_hindi = imdb[imdb['original_language'] == 'hi']

# %%
imdb1_hindi = imdb[imdb_cond]

# %%
imdb1_hindi.head()
# Out:
#       id belongs_to_collection    budget  \
# 3      4                   NaN   1200000
# 213  214                   NaN   6700000
# 371  372                   NaN  13100000
# 401  402                   NaN   3000000
# 419  420                   NaN   3750000
#
#                                                 genres  \
# 3    [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 213                     [{'id': 28, 'name': 'Action'}]
# 371  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 401  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 419  [{'id': 35, 'name': 'Comedy'}, {'id': 10769, '...
#
#                             homepage    imdb_id original_language  \
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 213                              NaN  tt2077833                hi
# 371  http://www.thankyouthefilm.com/  tt1720254                hi
# 401                              NaN  tt0319736                hi
# ...

# %%
imdb1_hindi.shape
# Out:
# (42, 23)

# %%
imdb1_ta = imdb[imdb['original_language'] == 'ta']
imdb1_ta.head()
# Out:
#       id                              belongs_to_collection   budget  \
# 76    77                                                NaN   500000
# 334  335                                                NaN        1
# 361  362  [{'id': 343944, 'name': 'Singam Collection', '...  2200000
# 516  517                                                NaN  2000000
# 524  525                                                NaN        0
#
#                                                 genres homepage    imdb_id  \
# 76   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN  tt0242572
# 334  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...      NaN  tt0376144
# 361  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...      NaN  tt1655607
# 516  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...      NaN  tt0242256
# 524  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...      NaN  tt0376127
#
#     original_language             original_title  \
# ...

# %% [markdown]
# #### CREATING A NEW COLUMN

# %%
imdb1_hindi['Profit'] = imdb1_hindi['revenue'] - imdb1_hindi['budget']
# Out:
# C:\Users\sudha\AppData\Local\Temp\ipykernel_7272\603346198.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb1_hindi['Profit'] = imdb1_hindi['revenue'] - imdb1_hindi['budget']

# %%
imdb1_hindi.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'Profit'],
#       dtype='object')

# %%
imdb1_hindi.head()
# Out:
#       id belongs_to_collection    budget  \
# 3      4                   NaN   1200000
# 213  214                   NaN   6700000
# 371  372                   NaN  13100000
# 401  402                   NaN   3000000
# 419  420                   NaN   3750000
#
#                                                 genres  \
# 3    [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 213                     [{'id': 28, 'name': 'Action'}]
# 371  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 401  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 419  [{'id': 35, 'name': 'Comedy'}, {'id': 10769, '...
#
#                             homepage    imdb_id original_language  \
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 213                              NaN  tt2077833                hi
# 371  http://www.thankyouthefilm.com/  tt1720254                hi
# 401                              NaN  tt0319736                hi
# ...

# %%
np.max(imdb1_hindi.Profit)
# Out:
# 299600000

# %%
np.min(imdb1_hindi.Profit)
# Out:
# -16500000

# %%
imdb1_hindi.Profit.idxmax()
# Out:
# 585

# %%
imdb1_hindi.iloc[3]
# Out:
# id                                                                     402
# belongs_to_collection                                                  NaN
# budget                                                             3000000
# genres                   [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# homepage                                                               NaN
# imdb_id                                                          tt0319736
# original_language                                                       hi
# original_title                                  The Legend of Bhagat Singh
# overview                 The Legend of Bhagat Singh is a 2002 Indian hi...
# popularity                                                        0.904409
# poster_path                               /z5FBA9RJTeg1PFk8vif5CrzhxL7.jpg
# production_companies                                                   NaN
# ...

# %%
imdb1_hindi.loc[401]
# Out:
# id                                                                     402
# belongs_to_collection                                                  NaN
# budget                                                             3000000
# genres                   [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# homepage                                                               NaN
# imdb_id                                                          tt0319736
# original_language                                                       hi
# original_title                                  The Legend of Bhagat Singh
# overview                 The Legend of Bhagat Singh is a 2002 Indian hi...
# popularity                                                        0.904409
# poster_path                               /z5FBA9RJTeg1PFk8vif5CrzhxL7.jpg
# production_companies                                                   NaN
# ...

# %%
imdb1_hindi.loc[585]
# Out:
# id                                                                     586
# belongs_to_collection                                                  NaN
# budget                                                            10400000
# genres                                       [{'id': 18, 'name': 'Drama'}]
# homepage                                                               NaN
# imdb_id                                                          tt5074352
# original_language                                                       hi
# original_title                                                        दंगल
# overview                 Dangal is an extraordinary true story based on...
# popularity                                                        8.792104
# poster_path                               /5PDT64gtbmH10gK5AYR7LZh5PQk.jpg
# production_companies     [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
# ...

# %%
imdb1_hindi['Profit_Per'] = (imdb1_hindi.Profit/imdb1_hindi.budget)*100
# Out:
# C:\Users\sudha\AppData\Local\Temp\ipykernel_7272\2082121045.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb1_hindi['Profit_Per'] = (imdb1_hindi.Profit/imdb1_hindi.budget)*100

# %%
imdb1_hindi.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'Profit', 'Profit_Per'],
#       dtype='object')

# %%
imdb1_hindi.head()
# Out:
#       id belongs_to_collection    budget  \
# 3      4                   NaN   1200000
# 213  214                   NaN   6700000
# 371  372                   NaN  13100000
# 401  402                   NaN   3000000
# 419  420                   NaN   3750000
#
#                                                 genres  \
# 3    [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 213                     [{'id': 28, 'name': 'Action'}]
# 371  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 401  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 419  [{'id': 35, 'name': 'Comedy'}, {'id': 10769, '...
#
#                             homepage    imdb_id original_language  \
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 213                              NaN  tt2077833                hi
# 371  http://www.thankyouthefilm.com/  tt1720254                hi
# 401                              NaN  tt0319736                hi
# ...

# %%
np.max(imdb1_hindi.Profit_Per)
# Out:
# inf

# %%
imdb1_hindi['Profit_Per'].idxmax()
# Out:
# 1766

# %%
imdb1_hindi['title'][imdb1_hindi['Profit_Per'].idxmax()]
# Out:
# 'Tum Bin'

# %%
imdb1_hindi.loc[1766]
# Out:
# id                                                                    1767
# belongs_to_collection                                                  NaN
# budget                                                                   0
# genres                   [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# homepage                                                               NaN
# imdb_id                                                          tt0290326
# original_language                                                       hi
# original_title                                                     Tum Bin
# overview                 Shekhar, a businessman, accidentally kills his...
# popularity                                                        0.371679
# poster_path                               /AvnU4mpqTb1v5NoIxtcc1aM3Joy.jpg
# production_companies     [{'name': 'Super Cassettes Industries Limited ...
# ...

# %%
imdb1_hindi['revenue'][imdb1_hindi['Profit_Per'].idxmax()]
# Out:
# 1486992

# %%
imdb1_hindi['tagline'][imdb1_hindi['Profit_Per'].idxmax()]
# Out:
# 'Love Will Find the Way'

# %%
imdb1_hindi.tail()
# Out:
#         id                              belongs_to_collection    budget  \
# 2807  2808                                                NaN   5300000
# 2828  2829                                                NaN  19500000
# 2857  2858                                                NaN   5400000
# 2859  2860  [{'id': 286951, 'name': 'Singham Collection', ...   3062000
# 2959  2960                                                NaN   2300000
#
#                                                  genres homepage    imdb_id  \
# 2807  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...      NaN  tt0439662
# 2828  [{'id': 10752, 'name': 'War'}, {'id': 36, 'nam...      NaN  tt3735246
# 2857                   [{'id': 53, 'name': 'Thriller'}]      NaN  tt2855648
# 2859  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN  tt1948150
# 2959  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...      NaN  tt1093370
#
#      original_language   original_title  \
# ...

# %%
imdb1_hindi['Profit_Per'].idxmin()
# Out:
# 2251

# %%
imdb1_hindi.loc[2251]
# Out:
# id                                                                    2252
# belongs_to_collection                                                  NaN
# budget                                                                 130
# genres                   [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# homepage                                                               NaN
# imdb_id                                                          tt1729637
# original_language                                                       hi
# original_title                                                   Bodyguard
# overview                 Lovely Singh (Salman Khan) is the bodyguard of...
# popularity                                                        2.402032
# poster_path                               /op9AWd9zGsa4rzjZLsGO8JMEYyA.jpg
# production_companies     [{'name': 'Reliance Entertainment', 'id': 7294...
# ...

# %%
imdb1_hindi.iloc[0]
# Out:
# id                                                                       4
# belongs_to_collection                                                  NaN
# budget                                                             1200000
# genres                   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# homepage                                        http://kahaanithefilm.com/
# imdb_id                                                          tt1821480
# original_language                                                       hi
# original_title                                                     Kahaani
# overview                 Vidya Bagchi (Vidya Balan) arrives in Kolkata ...
# popularity                                                        3.174936
# poster_path                               /aTXRaPrWSinhcmCrcfJK17urp3F.jpg
# production_companies                                                   NaN
# ...

# %% [markdown]
# #### DATA CLEANING

# %%
# REMOVE COLUMN

imdb1_hindi.drop('Profit_Per', axis = 1) # axis = 1 to do the task along columns
# Out:
#         id                              belongs_to_collection    budget  \
# 3        4                                                NaN   1200000
# 213    214                                                NaN   6700000
# 371    372                                                NaN  13100000
# 401    402                                                NaN   3000000
# 419    420                                                NaN   3750000
# 481    482                                                NaN  10500000
# 585    586                                                NaN  10400000
# 627    628                                                NaN  16000000
# 671    672                                                NaN   6400000
# 695    696                                                NaN         1
# 771    772                                                NaN   9000000
# 840    841                                                NaN  10721568
# ...

# %%
imdb1_hindi.head()
# Out:
#       id belongs_to_collection    budget  \
# 3      4                   NaN   1200000
# 213  214                   NaN   6700000
# 371  372                   NaN  13100000
# 401  402                   NaN   3000000
# 419  420                   NaN   3750000
#
#                                                 genres  \
# 3    [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 213                     [{'id': 28, 'name': 'Action'}]
# 371  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 401  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 419  [{'id': 35, 'name': 'Comedy'}, {'id': 10769, '...
#
#                             homepage    imdb_id original_language  \
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 213                              NaN  tt2077833                hi
# 371  http://www.thankyouthefilm.com/  tt1720254                hi
# 401                              NaN  tt0319736                hi
# ...

# %%
imdb2_hindi = imdb1_hindi.drop('Profit_Per', axis = 1) # axis = 1 to do the task along columns

# %%
imdb2_hindi.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'Profit'],
#       dtype='object')

# %%
imdb1_hindi = imdb1_hindi.drop('Profit_Per', axis = 1) # axis = 1 to do the task along columns

# %%
imdb1_hindi.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'Profit'],
#       dtype='object')

# %%
imdb1_hindi.drop('poster_path', axis = 1, inplace = True) 
 # inplace = True to drop in the actual dataset

# %%
imdb1_hindi.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'production_companies', 'production_countries',
#        'release_date', 'runtime', 'spoken_languages', 'status', 'tagline',
#        'title', 'Keywords', 'cast', 'crew', 'revenue', 'Profit'],
#       dtype='object')

# %%
imdb1_hindi.drop([371])# by default axis = 0 will be taken
# Out:
#         id                              belongs_to_collection    budget  \
# 3        4                                                NaN   1200000
# 213    214                                                NaN   6700000
# 401    402                                                NaN   3000000
# 419    420                                                NaN   3750000
# 481    482                                                NaN  10500000
# 585    586                                                NaN  10400000
# 627    628                                                NaN  16000000
# 671    672                                                NaN   6400000
# 695    696                                                NaN         1
# 771    772                                                NaN   9000000
# 840    841                                                NaN  10721568
# 848    849                                                NaN   6400000
# ...

# %%
imdb1_hindi.head()
# Out:
#       id belongs_to_collection    budget  \
# 3      4                   NaN   1200000
# 213  214                   NaN   6700000
# 371  372                   NaN  13100000
# 401  402                   NaN   3000000
# 419  420                   NaN   3750000
#
#                                                 genres  \
# 3    [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 213                     [{'id': 28, 'name': 'Action'}]
# 371  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 401  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 419  [{'id': 35, 'name': 'Comedy'}, {'id': 10769, '...
#
#                             homepage    imdb_id original_language  \
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 213                              NaN  tt2077833                hi
# 371  http://www.thankyouthefilm.com/  tt1720254                hi
# 401                              NaN  tt0319736                hi
# ...

# %%
imdb1_hindi.drop([213], axis = 0, inplace = True)

# %%
imdb1_hindi.head()
# Out:
#       id belongs_to_collection    budget  \
# 3      4                   NaN   1200000
# 371  372                   NaN  13100000
# 401  402                   NaN   3000000
# 419  420                   NaN   3750000
# 481  482                   NaN  10500000
#
#                                                 genres  \
# 3    [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 371  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 401  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 419  [{'id': 35, 'name': 'Comedy'}, {'id': 10769, '...
# 481  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                             homepage    imdb_id original_language  \
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 371  http://www.thankyouthefilm.com/  tt1720254                hi
# 401                              NaN  tt0319736                hi
# 419    http://www.atithithefilm.com/  tt1578116                hi
# ...

# %%
imdb1_hindi.drop(['id','revenue'], axis = 1)
# Out:
#                                   belongs_to_collection    budget  \
# 3                                                   NaN   1200000
# 371                                                 NaN  13100000
# 401                                                 NaN   3000000
# 419                                                 NaN   3750000
# 481                                                 NaN  10500000
# 585                                                 NaN  10400000
# 627                                                 NaN  16000000
# 671                                                 NaN   6400000
# 695                                                 NaN         1
# 771                                                 NaN   9000000
# 840                                                 NaN  10721568
# 848                                                 NaN   6400000
# 970                                                 NaN   4200000
# ...

# %%
imdb1_hindi.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'production_companies', 'production_countries',
#        'release_date', 'runtime', 'spoken_languages', 'status', 'tagline',
#        'title', 'Keywords', 'cast', 'crew', 'revenue', 'Profit'],
#       dtype='object')

# %%
imdb1_hindi.drop(imdb1_hindi.index[0:2]) # dropping multiple rows using implicit index Nos.
# Out:
#         id                              belongs_to_collection    budget  \
# 401    402                                                NaN   3000000
# 419    420                                                NaN   3750000
# 481    482                                                NaN  10500000
# 585    586                                                NaN  10400000
# 627    628                                                NaN  16000000
# 671    672                                                NaN   6400000
# 695    696                                                NaN         1
# 771    772                                                NaN   9000000
# 840    841                                                NaN  10721568
# 848    849                                                NaN   6400000
# 970    971                                                NaN   4200000
# 1004  1005                                                NaN   1000000
# ...

# %%
imdb1_hindi.drop([419, 481], axis = 0)  # drop multilpe rows with explicit index nos.
# Out:
#         id                              belongs_to_collection    budget  \
# 3        4                                                NaN   1200000
# 371    372                                                NaN  13100000
# 401    402                                                NaN   3000000
# 585    586                                                NaN  10400000
# 627    628                                                NaN  16000000
# 671    672                                                NaN   6400000
# 695    696                                                NaN         1
# 771    772                                                NaN   9000000
# 840    841                                                NaN  10721568
# 848    849                                                NaN   6400000
# 970    971                                                NaN   4200000
# 1004  1005                                                NaN   1000000
# ...

# %% [markdown]
# #### DEALING WITH NULL VALUES

# %%
imdb1_hindi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41 entries, 3 to 2959
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     41 non-null     int64
#  1   belongs_to_collection  4 non-null      object
#  2   budget                 41 non-null     int64
#  3   genres                 41 non-null     object
#  4   homepage               13 non-null     object
#  5   imdb_id                41 non-null     object
#  6   original_language      41 non-null     object
#  7   original_title         41 non-null     object
#  8   overview               41 non-null     object
#  9   popularity             41 non-null     float64
#  10  production_companies   37 non-null     object
#  11  production_countries   41 non-null     object
#  12  release_date           41 non-null     object
#  13  runtime                41 non-null     float64
# ...

# %%
imdb1_hindi.isnull().any()
# Out:
# id                       False
# belongs_to_collection     True
# budget                   False
# genres                   False
# homepage                  True
# imdb_id                  False
# original_language        False
# original_title           False
# overview                 False
# popularity               False
# production_companies      True
# production_countries     False
# release_date             False
# runtime                  False
# spoken_languages         False
# status                   False
# tagline                   True
# title                    False
# Keywords                  True
# cast                     False
# crew                     False
# revenue                  False
# Profit                   False
# dtype: bool

# %%
imdb1_hindi.isna().sum()
# Out:
# id                        0
# belongs_to_collection    37
# budget                    0
# genres                    0
# homepage                 28
# imdb_id                   0
# original_language         0
# original_title            0
# overview                  0
# popularity                0
# production_companies      4
# production_countries      0
# release_date              0
# runtime                   0
# spoken_languages          0
# status                    0
# tagline                  26
# title                     0
# Keywords                 12
# cast                      0
# crew                      0
# revenue                   0
# Profit                    0
# dtype: int64

# %%
imdb1_hindi['homepage_new'] = imdb1_hindi['homepage'].fillna('No Homepage')
imdb1_hindi.head()
# Out:
#       id belongs_to_collection    budget  \
# 3      4                   NaN   1200000
# 371  372                   NaN  13100000
# 401  402                   NaN   3000000
# 419  420                   NaN   3750000
# 481  482                   NaN  10500000
#
#                                                 genres  \
# 3    [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 371  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 401  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 419  [{'id': 35, 'name': 'Comedy'}, {'id': 10769, '...
# 481  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                             homepage    imdb_id original_language  \
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 371  http://www.thankyouthefilm.com/  tt1720254                hi
# 401                              NaN  tt0319736                hi
# 419    http://www.atithithefilm.com/  tt1578116                hi
# ...

# %%
imdb1_hindi['budget'] == 0
# Out:
# 3       False
# 371     False
# 401     False
# 419     False
# 481     False
# 585     False
# 627     False
# 671     False
# 695     False
# 771     False
# 840     False
# 848     False
# 970     False
# 1004    False
# 1491    False
# 1572    False
# 1640    False
# 1656    False
# 1694    False
# 1719    False
# 1729    False
# 1732    False
# 1766     True
# 1948     True
# 1987     True
# 1989    False
# 2239    False
# 2251    False
# 2287    False
# 2353    False
# 2390    False
# 2436    False
# 2480    False
# 2538    False
# 2563    False
# 2567    False
# 2807    False
# 2828    False
# 2857    False
# 2859    False
# 2959    False
# Name: budget, dtype: bool

# %%
imdb1_hindi['budget'] != 0
# Out:
# 3        True
# 371      True
# 401      True
# 419      True
# 481      True
# 585      True
# 627      True
# 671      True
# 695      True
# 771      True
# 840      True
# 848      True
# 970      True
# 1004     True
# 1491     True
# 1572     True
# 1640     True
# 1656     True
# 1694     True
# 1719     True
# 1729     True
# 1732     True
# 1766    False
# 1948    False
# 1987    False
# 1989     True
# 2239     True
# 2251     True
# 2287     True
# 2353     True
# 2390     True
# 2436     True
# 2480     True
# 2538     True
# 2563     True
# 2567     True
# 2807     True
# 2828     True
# 2857     True
# 2859     True
# 2959     True
# Name: budget, dtype: bool

# %%
imdb1_hindi[imdb1_hindi['budget'] != 0]
# Out:
#         id                              belongs_to_collection    budget  \
# 3        4                                                NaN   1200000
# 371    372                                                NaN  13100000
# 401    402                                                NaN   3000000
# 419    420                                                NaN   3750000
# 481    482                                                NaN  10500000
# 585    586                                                NaN  10400000
# 627    628                                                NaN  16000000
# 671    672                                                NaN   6400000
# 695    696                                                NaN         1
# 771    772                                                NaN   9000000
# 840    841                                                NaN  10721568
# 848    849                                                NaN   6400000
# ...
